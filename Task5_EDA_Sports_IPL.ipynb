# %% [markdown]
# ![GRIP%20SRU-2.jpg](attachment:GRIP%20SRU-2.jpg)

# %% [markdown]
# # Task-5: Exploratory Data Analysis on Sports (Indian Premier League)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Observation-of-Matches-dataset" data-toc-modified-id="Observation-of-Matches-dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Observation of Matches dataset</a></span></li><li><span><a href="#Observation-of-Deliveries-dataset" data-toc-modified-id="Observation-of-Deliveries-dataset-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Observation of Deliveries dataset</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Match-Results" data-toc-modified-id="Match-Results-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Match Results</a></span><ul class="toc-item"><li><span><a href="#Team-won-by-Maximum-Runs" data-toc-modified-id="Team-won-by-Maximum-Runs-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Team won by Maximum Runs</a></span></li><li><span><a href="#Team-won-by-Maximum-Wickets" data-toc-modified-id="Team-won-by-Maximum-Wickets-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Team won by Maximum Wickets</a></span></li><li><span><a href="#Team-won-by-Minimum-run" data-toc-modified-id="Team-won-by-Minimum-run-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Team won by Minimum run</a></span></li><li><span><a href="#Team-won-by-Minimum-Wickets" data-toc-modified-id="Team-won-by-Minimum-Wickets-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Team won by Minimum Wickets</a></span></li><li><span><a href="#Match-Results-Declared-by-DLS" data-toc-modified-id="Match-Results-Declared-by-DLS-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Match Results Declared by DLS</a></span></li></ul></li><li><span><a href="#Season-wise-Analysis" data-toc-modified-id="Season-wise-Analysis-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Season wise Analysis</a></span><ul class="toc-item"><li><span><a href="#Toatal-Number-of-Seasons" data-toc-modified-id="Toatal-Number-of-Seasons-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Toatal Number of Seasons</a></span></li><li><span><a href="#Number-of-Matches-per-Season" data-toc-modified-id="Number-of-Matches-per-Season-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Number of Matches per Season</a></span></li><li><span><a href="#Champions-of-the-Seasons" data-toc-modified-id="Champions-of-the-Seasons-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Champions of the Seasons</a></span></li><li><span><a href="#The-team-with-the-most-number-of-wins-per-season" data-toc-modified-id="The-team-with-the-most-number-of-wins-per-season-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>The team with the most number of wins per season</a></span></li><li><span><a href="#City-&amp;-Venues-of-Matches-Played-in-every-Season" data-toc-modified-id="City-&amp;-Venues-of-Matches-Played-in-every-Season-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>City &amp; Venues of Matches Played in every Season</a></span></li></ul></li><li><span><a href="#Analysis-of-Venues-&amp;-Cities-where-Matches-Played" data-toc-modified-id="Analysis-of-Venues-&amp;-Cities-where-Matches-Played-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Analysis of Venues &amp; Cities where Matches Played</a></span><ul class="toc-item"><li><span><a href="#Name-of-the-Venues-where--number-of-matches-Played" data-toc-modified-id="Name-of-the-Venues-where--number-of-matches-Played-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Name of the Venues where  number of matches Played</a></span></li></ul></li><li><span><a href="#Team-Analysis" data-toc-modified-id="Team-Analysis-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Team Analysis</a></span><ul class="toc-item"><li><span><a href="#Most-number-of-Matches-Played-by-a-Team" data-toc-modified-id="Most-number-of-Matches-Played-by-a-Team-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Most number of Matches Played by a Team</a></span></li><li><span><a href="#Most-number-of-matches-won-by-Team" data-toc-modified-id="Most-number-of-matches-won-by-Team-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Most number of matches won by Team</a></span></li><li><span><a href="#Best-Defending-Team" data-toc-modified-id="Best-Defending-Team-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Best Defending Team</a></span></li><li><span><a href="#Best-Chasing-Team" data-toc-modified-id="Best-Chasing-Team-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Best Chasing Team</a></span></li></ul></li><li><span><a href="#Toss-Analysis" data-toc-modified-id="Toss-Analysis-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Toss Analysis</a></span><ul class="toc-item"><li><span><a href="#The-team-that-won-the-most-number-of-Toss" data-toc-modified-id="The-team-that-won-the-most-number-of-Toss-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>The team that won the most number of Toss</a></span></li><li><span><a href="#Toss-Winner-Decision" data-toc-modified-id="Toss-Winner-Decision-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Toss Winner Decision</a></span></li><li><span><a href="#Toss-Winner-vs-Match-Winner" data-toc-modified-id="Toss-Winner-vs-Match-Winner-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Toss Winner vs Match Winner</a></span></li><li><span><a href="#Season-wise-Toss-winners-Decision" data-toc-modified-id="Season-wise-Toss-winners-Decision-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>Season wise Toss winners Decision</a></span></li></ul></li><li><span><a href="#Analysis-of-Batsman" data-toc-modified-id="Analysis-of-Batsman-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Analysis of Batsman</a></span><ul class="toc-item"><li><span><a href="#Most-number-of-Runs-by-a-Batsman" data-toc-modified-id="Most-number-of-Runs-by-a-Batsman-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Most number of Runs by a Batsman</a></span></li><li><span><a href="#Most-number-of-4s-by-a-Batsman" data-toc-modified-id="Most-number-of-4s-by-a-Batsman-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Most number of 4s by a Batsman</a></span></li><li><span><a href="#Most-number-of-6s-by-a-Batsman" data-toc-modified-id="Most-number-of-6s-by-a-Batsman-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>Most number of 6s by a Batsman</a></span></li></ul></li><li><span><a href="#Analysis-of-Bowlers" data-toc-modified-id="Analysis-of-Bowlers-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Analysis of Bowlers</a></span><ul class="toc-item"><li><span><a href="#Most-number-of-Wickets-by-a-Bowler" data-toc-modified-id="Most-number-of-Wickets-by-a-Bowler-3.7.1"><span class="toc-item-num">3.7.1&nbsp;&nbsp;</span>Most number of Wickets by a Bowler</a></span></li><li><span><a href="#Bowled-Most-number-of-Balls" data-toc-modified-id="Bowled-Most-number-of-Balls-3.7.2"><span class="toc-item-num">3.7.2&nbsp;&nbsp;</span>Bowled Most number of Balls</a></span></li><li><span><a href="#Kind-of-Dismissals" data-toc-modified-id="Kind-of-Dismissals-3.7.3"><span class="toc-item-num">3.7.3&nbsp;&nbsp;</span>Kind of Dismissals</a></span></li></ul></li><li><span><a href="#Analysis-of-Fielders" data-toc-modified-id="Analysis-of-Fielders-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Analysis of Fielders</a></span><ul class="toc-item"><li><span><a href="#Most-number-of-Catches-by-a-Player" data-toc-modified-id="Most-number-of-Catches-by-a-Player-3.8.1"><span class="toc-item-num">3.8.1&nbsp;&nbsp;</span>Most number of Catches by a Player</a></span></li><li><span><a href="#Most-number-of-Stumped-by-a-Wicket-Keeper" data-toc-modified-id="Most-number-of-Stumped-by-a-Wicket-Keeper-3.8.2"><span class="toc-item-num">3.8.2&nbsp;&nbsp;</span>Most number of Stumped by a Wicket Keeper</a></span></li></ul></li><li><span><a href="#Most-Valuable-Player-of-IPL" data-toc-modified-id="Most-Valuable-Player-of-IPL-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Most Valuable Player of IPL</a></span></li><li><span><a href="#Analysis-of-Umpires-standing-in-the-Matches" data-toc-modified-id="Analysis-of-Umpires-standing-in-the-Matches-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Analysis of Umpires standing in the Matches</a></span></li></ul></li><li><span><a href="#Inferences-and-Conclusion" data-toc-modified-id="Inferences-and-Conclusion-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Inferences and Conclusion</a></span></li></ul></div>

# %% [markdown]
# __Introduction:__
#
# The Indian Premier League (IPL) is a professional Twenty20 cricket league, contested by ten teams based out of ten Indian cities. The league was founded by the Board of Control for Cricket in India (BCCI) in 2007. It is usually held between March and May of every year and has an exclusive window in the ICC Future Tours Programme

# %% [markdown]
# __Problem Statement:__
#
# - find out the most successful teams,players and factors contributing win or loss of a team.

# %% [markdown]
# __Import Packages:__

# %%
import numpy as np                     
import pandas as pd

pd.set_option('mode.chained_assignment', None)      
pd.set_option('display.max_colwidth', -1)           
pd.options.display.max_columns = 50  
pd.set_option('display.max_rows', None)

import warnings
warnings.filterwarnings('ignore')                  

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)
# Out:
# <ipython-input-1-c48b7aba859a>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Observation of Matches dataset

# %% [markdown]
# __Data Description:__
#
# |Variables	    |Description
# |:-----------   |:-------------------------------- |
# | id	            | The id of the match                              |
# | season	        | The year the match was played                    |
# | city	            | The city in which the match was conducted        |
# | date	            | The date the match was conducted                 |
# | team1	            | Team1 of the match                               |
# | team2	            | Team2 of the match                               |
# | toss_winner	    | The team that won the toss                       |
# | toss_decision     | the toss winning team choose to bat or Field     |
# | result	        | what is the result type, normal,tie or no result |
# | dl_applied	    | whether the dl applied to find the result        |
# | winner	        | winner of the match                              |
# | win_by_runs	    | the margin of runs the team has won              |
# | win_by_wickets	| with how many wickets remaining the team has won |
# | player_of_match	| Player of the particular match                   |
# | venue	            | The venue name where the match was conducted     |
# | umpire1	        | Umpire1 of the match                             |
# | umpire2	        | umpire2 of the match                             |
# | umpire3	        | umpire3 of the match                             |

# %% [markdown]
# __Importing the Matches Dataset:__

# %%
matches = pd.read_csv('https://raw.githubusercontent.com/sruthayanan/TSF-GRIP/main/matches.csv')
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0  1   2017    Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1  2   2017    Pune       2017-04-06  Mumbai Indians
# 2  3   2017    Rajkot     2017-04-07  Gujarat Lions
# 3  4   2017    Indore     2017-04-08  Rising Pune Supergiant
# 4  5   2017    Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  field
# 1  Rising Pune Supergiant       Rising Pune Supergiant       field
# 2  Kolkata Knight Riders        Kolkata Knight Riders        field
# 3  Kings XI Punjab              Kings XI Punjab              field
# 4  Delhi Daredevils             Royal Challengers Bangalore  bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal  0           Sunrisers Hyderabad          35
# 1  normal  0           Rising Pune Supergiant       0
# ...

# %% [markdown]
# __Data Exploration: Understanding the Matches Dataset__

# %%
matches.shape
# Out:
# (756, 18)

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
matches.describe(include="all")
# Out:
#                   id       season    city        date           team1  \
# count   756.000000    756.000000   749     756         756
# unique NaN           NaN           32      546         15
# top    NaN           NaN           Mumbai  2014-05-07  Mumbai Indians
# freq   NaN           NaN           101     2           101
# mean    1792.178571   2013.444444  NaN     NaN         NaN
# std     3464.478148   3.366895     NaN     NaN         NaN
# min     1.000000      2008.000000  NaN     NaN         NaN
# 25%     189.750000    2011.000000  NaN     NaN         NaN
# 50%     378.500000    2013.000000  NaN     NaN         NaN
# 75%     567.250000    2016.000000  NaN     NaN         NaN
# max     11415.000000  2019.000000  NaN     NaN         NaN
#
#                         team2     toss_winner toss_decision  result  \
# count   756                    756             756           756
# unique  15                     15              2             3
# ...

# %%
matches.duplicated().sum()
# Out:
# 0

# %%
null_data = pd.DataFrame(matches.isnull().sum(), columns = ['Frequency'])
null_data.transpose()
# Out:
#            id  season  city  date  team1  team2  toss_winner  toss_decision  \
# Frequency  0   0       7     0     0      0      0            0
#
#            result  dl_applied  winner  win_by_runs  win_by_wickets  \
# Frequency  0       0           4       0            0
#
#            player_of_match  venue  umpire1  umpire2  umpire3
# Frequency  4                0      2        2        637

# %% [markdown]
# __Missing Value Treatment__

# %%
matches.drop(['umpire3'],1,inplace=True)

# %% [markdown]
# - Filling null values in City Column

# %%
matches[matches.city.isnull()].head(10)
# Out:
#       id  season city        date                        team1  \
# 461  462  2014    NaN  2014-04-19  Mumbai Indians
# 462  463  2014    NaN  2014-04-19  Kolkata Knight Riders
# 466  467  2014    NaN  2014-04-23  Chennai Super Kings
# 468  469  2014    NaN  2014-04-25  Sunrisers Hyderabad
# 469  470  2014    NaN  2014-04-25  Mumbai Indians
# 474  475  2014    NaN  2014-04-28  Royal Challengers Bangalore
# 476  477  2014    NaN  2014-04-30  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 461  Royal Challengers Bangalore  Royal Challengers Bangalore  field
# 462  Delhi Daredevils             Kolkata Knight Riders        bat
# 466  Rajasthan Royals             Rajasthan Royals             field
# 468  Delhi Daredevils             Sunrisers Hyderabad          bat
# 469  Chennai Super Kings          Mumbai Indians               bat
# 474  Kings XI Punjab              Kings XI Punjab              field
# ...

# %% [markdown]
# - all 7 mathes were played in Dubai International Cricket Stadium, hence we can fill the missing city as Dubai.

# %%
matches['city']= matches['city'].replace(np.NaN, 'Dubai')

# %%
matches[matches.winner.isnull()].head(10)
# Out:
#         id  season       city        date                        team1  \
# 300  301    2011    Delhi      2011-05-21  Delhi Daredevils
# 545  546    2015    Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015    Bangalore  2015-05-17  Delhi Daredevils
# 744  11340  2019    Bengaluru  30/04/19    Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 300  Pune Warriors                Delhi Daredevils             bat
# 545  Rajasthan Royals             Rajasthan Royals             field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore  field
# 744  Rajasthan Royals             Rajasthan Royals             field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result  0           NaN    0            0
# 545  no result  0           NaN    0            0
# 570  no result  0           NaN    0            0
# 744  no result  0           NaN    0            0
#
# ...

# %%
matches['winner']= matches['winner'].replace(np.NaN, 'no result')
matches['player_of_match']= matches['player_of_match'].replace(np.NaN, 'no result')

# %%
matches[matches.umpire1.isnull()].head()
# Out:
#         id  season           city        date                        team1  \
# 4    5      2017    Bangalore      2017-04-08  Royal Challengers Bangalore
# 753  11413  2019    Visakhapatnam  08/05/19    Sunrisers Hyderabad
#
#                 team2                  toss_winner toss_decision  result  \
# 4    Delhi Daredevils  Royal Challengers Bangalore  bat           normal
# 753  Delhi Capitals    Delhi Capitals               field         normal
#
#      dl_applied                       winner  win_by_runs  win_by_wickets  \
# 4    0           Royal Challengers Bangalore  15           0
# 753  0           Delhi Capitals               0            2
#
#     player_of_match                  venue umpire1 umpire2
# 4    KM Jadhav       M Chinnaswamy Stadium  NaN     NaN
# 753  RR Pant         ACA-VDCA Stadium       NaN     NaN

# %%
matches.team1.value_counts()
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                91
# Chennai Super Kings            89
# Royal Challengers Bangalore    85
# Kolkata Knight Riders          83
# Delhi Daredevils               72
# Rajasthan Royals               67
# Sunrisers Hyderabad            63
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant         8
# Rising Pune Supergiants        7
# Kochi Tuskers Kerala           7
# Delhi Capitals                 6
# Name: team1, dtype: int64

# %%
matches.team2.value_counts()
# Out:
# Kolkata Knight Riders          95
# Royal Challengers Bangalore    95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            75
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant         8
# Rising Pune Supergiants        7
# Kochi Tuskers Kerala           7
# Name: team2, dtype: int64

# %%
matches.winner.value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders          92
# Royal Challengers Bangalore    84
# Kings XI Punjab                82
# Rajasthan Royals               75
# Delhi Daredevils               67
# Sunrisers Hyderabad            58
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Delhi Capitals                 10
# Kochi Tuskers Kerala           6
# Rising Pune Supergiants        5
# no result                      4
# Name: winner, dtype: int64

# %%
matches.toss_winner.value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Kings XI Punjab                81
# Royal Challengers Bangalore    81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala           8
# Rising Pune Supergiants        7
# Rising Pune Supergiant         6
# Name: toss_winner, dtype: int64

# %% [markdown]
# Team name of __Rising Pune Supergiants__ were present an __Rising Pune Supergiant__ in some places, this needs to be renamed

# %%
matches[['team1','team2','winner','toss_winner']]= matches[['team1','team2','winner','toss_winner']].replace('Rising Pune Supergiant', 'Rising Pune Supergiants')

# %% [markdown]
# ## Observation of Deliveries dataset

# %% [markdown]
# __Data Description:__
#
# |Variables	    |Description
# |:-----------   |:-------------------------------- |
# | match_id	        | The id of the match                                           |
# | inning        	| The innings no. 1,2,3 or 4                                    |
# | batting_team  	| The team that doing batting                                   |
# | bowling_team   	| The team that doing bowling                                   |
# | over              | The present ongoing over                                      |
# | ball	            | which ball of the over                                        |
# | batsman       	| The batsman who is facing the ball                            |
# | non_striker   	| The batsman at the non-strikers end                           |
# | bowler        	| The bowler doing bowling                                      |
# | is_super_over	    | Is it a super over or not                                     |
# | wide_runs     	| wide runs given by the bowler                                 |
# | bye_runs      	| bye runs given by the bowler                                  |
# | legbye_runs   	| legbye runs given by the bowler                               |
# | noball_runs	    | noball runs given by the bowler                               |
# | penalty_runs  	| penalty runs given to the batting team                        |
# | batsman_runs  	| the runs hit by batsman                                       |
# | extra_runs	    | the extra runs given by the bowler                            |
# | total_runs	    | total runs conceded by bowler in that particular delivery     |
# | player_dismissed	| The player that got dismissed during that particular delivery |
# | dismissal_kind	| what is the way the batsman got out                           |
# | fielder	        | the fielder involved in that particular delivery              |

# %% [markdown]
# __Importing the Deliveries Dataset:__

# %%
deliveries = pd.read_csv('https://raw.githubusercontent.com/sruthayanan/TSF-GRIP/main/deliveries.csv')
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1
# 1  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1
# 2  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1
# 3  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1
# 4  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1
#
#    ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  \
# 0  1     DA Warner  S Dhawan    TS Mills  0              0          0
# 1  2     DA Warner  S Dhawan    TS Mills  0              0          0
# 2  3     DA Warner  S Dhawan    TS Mills  0              0          0
# 3  4     DA Warner  S Dhawan    TS Mills  0              0          0
# 4  5     DA Warner  S Dhawan    TS Mills  0              2          0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# __Data Exploration: Understanding the Deliveries Dataset__

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
deliveries.describe(include="all")
# Out:
#              match_id         inning    batting_team    bowling_team  \
# count   179078.000000  179078.000000  179078          179078
# unique NaN            NaN             15              15
# top    NaN            NaN             Mumbai Indians  Mumbai Indians
# freq   NaN            NaN             22619           22517
# mean    1802.252957    1.482952       NaN             NaN
# std     3472.322805    0.502074       NaN             NaN
# min     1.000000       1.000000       NaN             NaN
# 25%     190.000000     1.000000       NaN             NaN
# 50%     379.000000     1.000000       NaN             NaN
# 75%     567.000000     2.000000       NaN             NaN
# max     11415.000000   5.000000       NaN             NaN
#
#                  over           ball  batsman non_striker           bowler  \
# count   179078.000000  179078.000000  179078   179078      179078
# unique NaN            NaN             516      511         405
# ...

# %%
deliveries.duplicated().sum()
# Out:
# 23

# %%
deliveries = deliveries.drop_duplicates()

# %%
deliveries.shape
# Out:
# (179055, 21)

# %%
null_data = pd.DataFrame(deliveries.isnull().sum(), columns = ['Frequency'])
null_data.transpose()
# Out:
#            match_id  inning  batting_team  bowling_team  over  ball  batsman  \
# Frequency  0         0       0             0             0     0     0
#
#            non_striker  bowler  is_super_over  wide_runs  bye_runs  \
# Frequency  0            0       0              0          0
#
#            legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# Frequency  0            0            0             0             0
#
#            total_runs  player_dismissed  dismissal_kind  fielder
# Frequency  0           170221            170221          172607

# %% [markdown]
# __Missing Value Treatment__

# %%
deliveries['player_dismissed'] = deliveries.player_dismissed.fillna('0')

# %%
deliveries['dismissal_kind'] = deliveries.dismissal_kind.fillna('0')

# %%
deliveries['fielder'] = deliveries.fielder.fillna('0')

# %%
null_data = pd.DataFrame(deliveries.isnull().sum(), columns = ['Frequency'])
null_data.transpose()
# Out:
#            match_id  inning  batting_team  bowling_team  over  ball  batsman  \
# Frequency  0         0       0             0             0     0     0
#
#            non_striker  bowler  is_super_over  wide_runs  bye_runs  \
# Frequency  0            0       0              0          0
#
#            legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# Frequency  0            0            0             0             0
#
#            total_runs  player_dismissed  dismissal_kind  fielder
# Frequency  0           170221            170221          172607

# %%
# create a function for labeling #
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.02*height,
                '%d' % int(height),
                ha='center', va='bottom')

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Match Results

# %%
matches.result.value_counts()
# Out:
# normal       743
# tie          9
# no result    4
# Name: result, dtype: int64

# %%
sns.countplot(x='result',data=matches)
# Out:
# <AxesSubplot:xlabel='result', ylabel='count'>

# %% [markdown]
# #### Team won by Maximum Runs

# %%
matches.iloc[matches['win_by_runs'].idxmax()]
# Out:
# id                 44
# season             2017
# city               Delhi
# date               2017-05-06
# team1              Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision      field
# result             normal
# dl_applied         0
# winner             Mumbai Indians
# win_by_runs        146
# win_by_wickets     0
# player_of_match    LMP Simmons
# venue              Feroz Shah Kotla
# umpire1            Nitin Menon
# umpire2            CK Nandan
# Name: 43, dtype: object

# %% [markdown]
# - __Mumbai Indians__ defeated __Delhi Daredevils__ by 146 runs on 06 May 2017 at Feroz Shah Kotla stadium, Delhi.

# %% [markdown]
# #### Team won by Maximum Wickets

# %%
matches.iloc[matches['win_by_wickets'].idxmax()]
# Out:
# id                 3
# season             2017
# city               Rajkot
# date               2017-04-07
# team1              Gujarat Lions
# team2              Kolkata Knight Riders
# toss_winner        Kolkata Knight Riders
# toss_decision      field
# result             normal
# dl_applied         0
# winner             Kolkata Knight Riders
# win_by_runs        0
# win_by_wickets     10
# player_of_match    CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1            Nitin Menon
# umpire2            CK Nandan
# Name: 2, dtype: object

# %% [markdown]
# - __Kolkata Knight Riders__ defeated __Gujarat Lions__ by 10 wickets on 07 April 2017 at Saurashtra Cricket Association Stadium, Rajkot.

# %% [markdown]
# #### Team won by Minimum run

# %%
matches.iloc[matches[matches['win_by_runs'].ge(1)].win_by_runs.idxmin()]
# Out:
# id                 59
# season             2017
# city               Hyderabad
# date               2017-05-21
# team1              Mumbai Indians
# team2              Rising Pune Supergiants
# toss_winner        Mumbai Indians
# toss_decision      bat
# result             normal
# dl_applied         0
# winner             Mumbai Indians
# win_by_runs        1
# win_by_wickets     0
# player_of_match    KH Pandya
# venue              Rajiv Gandhi International Stadium, Uppal
# umpire1            NJ Llong
# umpire2            S Ravi
# Name: 58, dtype: object

# %% [markdown]
# - __Mumbai Indians__ defeated __Rising Pune Supergiants__ by 1 run on 21 May 2017 at Rajiv Gandhi International Stadium, Hyderabad.

# %% [markdown]
# #### Team won by Minimum Wickets

# %%
matches.iloc[matches[matches['win_by_wickets'].ge(1)].win_by_wickets.idxmin()]
# Out:
# id                 560
# season             2015
# city               Kolkata
# date               2015-05-09
# team1              Kings XI Punjab
# team2              Kolkata Knight Riders
# toss_winner        Kings XI Punjab
# toss_decision      bat
# result             normal
# dl_applied         0
# winner             Kolkata Knight Riders
# win_by_runs        0
# win_by_wickets     1
# player_of_match    AD Russell
# venue              Eden Gardens
# umpire1            AK Chaudhary
# umpire2            HDPK Dharmasena
# Name: 559, dtype: object

# %% [markdown]
# - __Kolkata Knight Riders__ defeated __Kings XI Punjab__ by 1 wicket on 09 May 2015 at Eden Gardens, Kolkata.

# %% [markdown]
# #### Match Results Declared by DLS

# %%
matches.city[matches.dl_applied==1].value_counts()
# Out:
# Kolkata          4
# Bangalore        3
# Delhi            3
# Hyderabad        2
# Visakhapatnam    2
# Cape Town        1
# Durban           1
# Kochi            1
# Jaipur           1
# Centurion        1
# Name: city, dtype: int64

# %%
plt.subplots(figsize=(12,8))
sns.countplot(matches.city[matches.dl_applied==1])
plt.xticks(rotation=90);

# %% [markdown]
# ### Season wise Analysis

# %% [markdown]
# #### Toatal Number of Seasons

# %%
matches['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %%
print('Total Seasons IPL were Observed in this Dataset:',len(matches['season'].unique()))
# Out:
# Total Seasons IPL were Observed in this Dataset: 12

# %% [markdown]
# #### Number of Matches per Season

# %%
plt.subplots(figsize=(12,8))
sns.countplot(x='season',data=matches)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %% [markdown]
# In 2013, we have the most number of matches

# %%
matches.season.value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %% [markdown]
# #### Champions of the Seasons

# %%
matches.drop_duplicates(subset=['season'], keep='last')[['season', 'winner']].reset_index(drop=True)
# Out:
#     season                 winner
# 0   2017    Mumbai Indians
# 1   2008    Rajasthan Royals
# 2   2009    Deccan Chargers
# 3   2010    Chennai Super Kings
# 4   2011    Chennai Super Kings
# 5   2012    Kolkata Knight Riders
# 6   2013    Mumbai Indians
# 7   2014    Kolkata Knight Riders
# 8   2015    Mumbai Indians
# 9   2016    Sunrisers Hyderabad
# 10  2018    Chennai Super Kings
# 11  2019    Mumbai Indians

# %% [markdown]
# #### The team with the most number of wins per season

# %%
teams_per_season = matches.groupby('season')['winner'].value_counts()
teams_per_season
# Out:
# season  winner
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings            9
#         Delhi Daredevils               7
#         Mumbai Indians                 7
#         Kolkata Knight Riders          6
#         Royal Challengers Bangalore    4
#         Deccan Chargers                2
# 2009    Delhi Daredevils               10
#         Deccan Chargers                9
#         Royal Challengers Bangalore    9
#         Chennai Super Kings            8
#         Kings XI Punjab                7
#         Rajasthan Royals               6
#         Mumbai Indians                 5
#         Kolkata Knight Riders          3
# 2010    Mumbai Indians                 11
#         Chennai Super Kings            9
#         Deccan Chargers                8
#         Royal Challengers Bangalore    8
#         Delhi Daredevils               7
#         Kolkata Knight Riders          7
# ...

# %%
year = 2008
win_per_season_df = pd.DataFrame(columns=['year', 'team', 'wins'])
for items in teams_per_season.iteritems():    
    if items[0][0]==year:
        print(items)
        win_series = pd.DataFrame({
            'year': [items[0][0]],
            'team': [items[0][1]],
            'wins': [items[1]]
        })
        win_per_season_df = win_per_season_df.append(win_series)
        year += 1
              
win_per_season_df
# Out:
# ((2008, 'Rajasthan Royals'), 13)
# ((2009, 'Delhi Daredevils'), 10)
# ((2010, 'Mumbai Indians'), 11)
# ((2011, 'Chennai Super Kings'), 11)
# ((2012, 'Kolkata Knight Riders'), 12)
# ((2013, 'Mumbai Indians'), 13)
# ((2014, 'Kings XI Punjab'), 12)
# ((2015, 'Chennai Super Kings'), 10)
# ((2016, 'Sunrisers Hyderabad'), 11)
# ((2017, 'Mumbai Indians'), 12)
# ((2018, 'Chennai Super Kings'), 11)
# ((2019, 'Mumbai Indians'), 11)
#    year                   team wins
# 0  2008  Rajasthan Royals       13
# 0  2009  Delhi Daredevils       10
# 0  2010  Mumbai Indians         11
# 0  2011  Chennai Super Kings    11
# 0  2012  Kolkata Knight Riders  12
# 0  2013  Mumbai Indians         13
# 0  2014  Kings XI Punjab        12
# 0  2015  Chennai Super Kings    10
# 0  2016  Sunrisers Hyderabad    11
# 0  2017  Mumbai Indians         12
# 0  2018  Chennai Super Kings    11
# 0  2019  Mumbai Indians         11

# %% [markdown]
# #### City & Venues of Matches Played in every Season

# %%
matches.groupby('season')['city'].value_counts()
# Out:
# season  city
# 2008    Mumbai            10
#         Bangalore         7
#         Chandigarh        7
#         Chennai           7
#         Hyderabad         7
#         Jaipur            7
#         Kolkata           7
#         Delhi             6
# 2009    Durban            15
#         Centurion         12
#         Johannesburg      8
#         Cape Town         7
#         Port Elizabeth    7
#         East London       3
#         Kimberley         3
#         Bloemfontein      2
# 2010    Mumbai            13
#         Bangalore         7
#         Chennai           7
#         Delhi             7
#         Kolkata           7
#         Chandigarh        5
#         Ahmedabad         4
#         Jaipur            3
#         Nagpur            3
#         Cuttack           2
#         Dharamsala        2
# 2011    Mumbai            16
#         Chennai           9
#         Delhi             7
#         Hyderabad         7
#         Jaipur            7
# ...

# %%
matches.groupby('season')['venue'].value_counts()
# Out:
# season  venue
# 2008    Eden Gardens                                            7
#         M Chinnaswamy Stadium                                   7
#         MA Chidambaram Stadium, Chepauk                         7
#         Punjab Cricket Association Stadium, Mohali              7
#         Rajiv Gandhi International Stadium, Uppal               7
#         Sawai Mansingh Stadium                                  7
#         Feroz Shah Kotla                                        6
#         Wankhede Stadium                                        6
#         Dr DY Patil Sports Academy                              4
# 2009    Kingsmead                                               15
#         SuperSport Park                                         12
#         New Wanderers Stadium                                   8
#         Newlands                                                7
#         St George's Park                                        7
# ...

# %% [markdown]
# ### Analysis of Venues & Cities where Matches Played

# %% [markdown]
# #### Name of the Venues where  number of matches Played

# %%
matches.city.value_counts()
# Out:
# Mumbai            101
# Kolkata           77
# Delhi             74
# Bangalore         66
# Hyderabad         64
# Chennai           57
# Jaipur            47
# Chandigarh        46
# Pune              38
# Durban            15
# Bengaluru         14
# Visakhapatnam     13
# Centurion         12
# Ahmedabad         12
# Mohali            10
# Rajkot            10
# Dharamsala        9
# Indore            9
# Johannesburg      8
# Abu Dhabi         7
# Port Elizabeth    7
# Ranchi            7
# Cape Town         7
# Dubai             7
# Cuttack           7
# Sharjah           6
# Raipur            6
# Kochi             5
# Kanpur            4
# East London       3
# Kimberley         3
# Nagpur            3
# Bloemfontein      2
# Name: city, dtype: int64

# %%
plt.subplots(figsize=(12,8))
sns.countplot(data=matches,x='city',order = matches.city.value_counts().index)
plt.xticks(rotation=90);

# %% [markdown]
# - __Mumbai__ city has hosted the maximum number of IPL matches

# %%
plt.figure(figsize=(12,10))
sns.countplot(y='venue',data=matches,order=matches.venue.value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='venue'>

# %%
matches.venue.value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Brabourne Stadium                                       11
# ...

# %% [markdown]
# - __Eden Gardens__ has hosted the maximum number of IPL matches followed by __Wankhede Stadium__ and __M Chinnaswamy Stadium__

# %% [markdown]
# ### Team Analysis

# %% [markdown]
# #### Most number of Matches Played by a Team

# %%
total_matches = (matches.team1.value_counts())+ (matches.team2.value_counts())
plt.rcParams["figure.figsize"] = (12, 6)
total_matches.sort_values(ascending=False).plot(kind='barh',cmap= 'Accent')
# Out:
# <AxesSubplot:>

# %%
total_matches.sort_values(ascending=False)
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                75
# Pune Warriors                  46
# Rising Pune Supergiants        30
# Gujarat Lions                  30
# Delhi Capitals                 16
# Kochi Tuskers Kerala           14
# dtype: int64

# %% [markdown]
# - __Mumbai Indians__ Played Most number of Matches followed by __Royal Challengers Bangalore__

# %% [markdown]
# #### Most number of matches won by Team

# %%
plt.subplots(figsize=(12,8))
sns.countplot(data=matches,x='winner',order = matches.winner.value_counts().index)
plt.xticks(rotation=90);

# %%
matches.winner.value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders          92
# Royal Challengers Bangalore    84
# Kings XI Punjab                82
# Rajasthan Royals               75
# Delhi Daredevils               67
# Sunrisers Hyderabad            58
# Deccan Chargers                29
# Rising Pune Supergiants        15
# Gujarat Lions                  13
# Pune Warriors                  12
# Delhi Capitals                 10
# Kochi Tuskers Kerala           6
# no result                      4
# Name: winner, dtype: int64

# %% [markdown]
# - __Mumbai Indians__ is the most successful team followed by __Chennai Super Kings__ and __Kolkata Knight Riders.__

# %% [markdown]
# #### Best Defending Team

# %%
Best_defending_team = matches.groupby('winner')['win_by_runs'].agg(lambda x:(x!=0).sum()).reset_index().sort_values(by='win_by_runs',ascending=False).reset_index(drop=True)
Best_defending_team
# Out:
#                          winner  win_by_runs
# 0   Mumbai Indians               57
# 1   Chennai Super Kings          52
# 2   Kings XI Punjab              38
# 3   Kolkata Knight Riders        36
# 4   Royal Challengers Bangalore  35
# 5   Sunrisers Hyderabad          30
# 6   Rajasthan Royals             27
# 7   Delhi Daredevils             25
# 8   Deccan Chargers              18
# 9   Rising Pune Supergiants      7
# 10  Pune Warriors                6
# 11  Delhi Capitals               3
# 12  Kochi Tuskers Kerala         2
# 13  Gujarat Lions                1
# 14  no result                    0

# %% [markdown]
# #### Best Chasing Team

# %%
Best_chasing_team = matches.groupby('winner')['win_by_wickets'].agg(lambda x:(x==0).sum()).reset_index().sort_values(by='win_by_wickets',ascending=False).reset_index(drop=True)
Best_chasing_team
# Out:
#                          winner  win_by_wickets
# 0   Mumbai Indians               59
# 1   Chennai Super Kings          52
# 2   Kings XI Punjab              40
# 3   Kolkata Knight Riders        36
# 4   Royal Challengers Bangalore  36
# 5   Sunrisers Hyderabad          31
# 6   Rajasthan Royals             29
# 7   Delhi Daredevils             25
# 8   Deccan Chargers              18
# 9   Rising Pune Supergiants      7
# 10  Pune Warriors                6
# 11  Delhi Capitals               4
# 12  no result                    4
# 13  Kochi Tuskers Kerala         2
# 14  Gujarat Lions                1

# %% [markdown]
# ### Toss Analysis

# %% [markdown]
# #### The team that won the most number of Toss

# %%
matches.toss_winner.value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Kings XI Punjab                81
# Royal Challengers Bangalore    81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiants        13
# Delhi Capitals                 10
# Kochi Tuskers Kerala           8
# Name: toss_winner, dtype: int64

# %%
sns.countplot(x='toss_winner',data=matches, order=matches.toss_winner.value_counts().index) 
plt.xticks(rotation=90);

# %% [markdown]
# - __Mumbai Indians__ has won the most toss in IPL history

# %% [markdown]
# #### Toss Winner Decision

# %%
toss = matches.toss_decision.value_counts()
labels = (np.array(toss.index))
sizes = (np.array((toss / toss.sum())*100))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("Toss decision percentage")
plt.show()

# %% [markdown]
# - 61% of the toss decisions are made to field first.

# %% [markdown]
# #### Toss Winner vs Match Winner

# %%
df=matches[matches['toss_winner']==matches['winner']]
slices=[len(df),(696-len(df))]
labels=['yes','no']
plt.pie(slices,labels=labels,startangle=90,shadow=True,textprops={'fontsize': 14},explode=(0,0.05),autopct='%1.1f%%',colors=['r','g'])
plt.figure(figsize= (20,12))
plt.show()

# %% [markdown]
# - 56.6% of the toss winner had won the Matches

# %% [markdown]
# #### Season wise Toss winners Decision

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='season', hue='toss_decision', data=matches)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# - During the initial years, teams wanted to bat first. 2016 onwards, most of the toss decisions are to field first.

# %% [markdown]
# ### Analysis of Batsman

# %% [markdown]
# #### Most number of Runs by a Batsman

# %%
mostruns = deliveries.groupby('batsman')['batsman_runs'].agg(sum).reset_index().sort_values(by='batsman_runs',ascending=False).reset_index(drop=True)
mostruns.head(10)
# Out:
#           batsman  batsman_runs
# 0  V Kohli         5434
# 1  SK Raina        5415
# 2  RG Sharma       4914
# 3  DA Warner       4741
# 4  S Dhawan        4631
# 5  CH Gayle        4560
# 6  MS Dhoni        4477
# 7  RV Uthappa      4444
# 8  AB de Villiers  4428
# 9  G Gambhir       4223

# %% [markdown]
# #### Most number of 4s by a Batsman

# %%
df_4s = deliveries.groupby('batsman')['batsman_runs'].agg(lambda x: (x==4).sum()).reset_index().sort_values(by='batsman_runs', ascending=False).reset_index(drop=True)
df_4s = df_4s.iloc[:10,:]

# %%
labels = np.array(df_4s['batsman'])
ind = np.arange(len(labels))
width = 0.9
fig, ax = plt.subplots(figsize=(15,8))
rects = ax.bar(ind, np.array(df_4s['batsman_runs']), width=width)
ax.set_xticks(ind+((width)/2.))
ax.set_xticklabels(labels, rotation='vertical')
ax.set_ylabel("Count")
ax.set_title("Batsman with most number of 4s.!",fontsize = 10)
autolabel(rects)
plt.show()

# %% [markdown]
# - __Dhawan__ is leading the chart by 526 4s, closely followed by __Raina__ and __Gambhir__

# %% [markdown]
# #### Most number of 6s by a Batsman

# %%
df_6s = deliveries.groupby('batsman')['batsman_runs'].agg(lambda x: (x==6).sum()).reset_index().sort_values(by='batsman_runs', ascending=False).reset_index(drop=True)
df_6s = df_6s.iloc[:10,:]

# %%
labels = np.array(df_6s['batsman'])
ind = np.arange(len(labels))
width = 0.9
fig, ax = plt.subplots(figsize=(15,8))
rects = ax.bar(ind, np.array(df_6s['batsman_runs']), width=width)
ax.set_xticks(ind+((width)/2.))
ax.set_xticklabels(labels, rotation='vertical')
ax.set_ylabel("Count")
ax.set_title("Batsman with most number of 6s.!",fontsize = 10)
autolabel(rects)
plt.show()

# %% [markdown]
# - __Gayle__ is way ahead of others, almost 113 Sixes more than __AB de Villiers__

# %% [markdown]
# ### Analysis of Bowlers

# %% [markdown]
# #### Most number of Wickets by a Bowler

# %%
df_wkts = deliveries.groupby('bowler')['player_dismissed'].agg(lambda x: (x!=0).sum()).reset_index().sort_values(by='player_dismissed', ascending=False).reset_index(drop=True)
df_wkts = df_wkts.iloc[:10,:]

# %%
labels = np.array(df_wkts['bowler'])
ind = np.arange(len(labels))
width = 0.9
fig, ax = plt.subplots(figsize=(15,8))
rects = ax.bar(ind, np.array(df_wkts['player_dismissed']), width=width)
ax.set_xticks(ind+((width)/2.))
ax.set_xticklabels(labels, rotation='vertical')
ax.set_ylabel("Count")
ax.set_title("Bowlern with most number of Wickets.!",fontsize = 10)
autolabel(rects)
plt.show()

# %% [markdown]
# - __Harbhajan Singh__ is leading the chart by 3451 wickets, closely followed by __A Mishra__ and __PP Chawla__

# %% [markdown]
# #### Bowled Most number of Balls

# %%
df_bowl = deliveries.groupby('bowler')['ball'].agg('count').reset_index().sort_values(by='ball', ascending=False).reset_index(drop=True)
df_bowl = df_bowl.iloc[:10,:]

# %%
labels = np.array(df_bowl['bowler'])
ind = np.arange(len(labels))
width = 0.9
fig, ax = plt.subplots(figsize=(15,8))
rects = ax.bar(ind, np.array(df_bowl['ball']), width=width)
ax.set_xticks(ind+((width)/2.))
ax.set_xticklabels(labels, rotation='vertical')
ax.set_ylabel("Count")
ax.set_title("Top Bowlers - Number of balls bowled in IPL")
ax.set_xlabel('Bowler Names')
autolabel(rects)
plt.show()

# %% [markdown]
# - __Harbhajan Singh__ is the the bowler with most number of balls bowled in IPL matches

# %% [markdown]
# #### Kind of Dismissals

# %%
deliveries.dismissal_kind.value_counts()
# Out:
# caught                   5348
# bowled                   1581
# run out                  852
# lbw                      540
# stumped                  278
# caught and bowled        211
# retired hurt             12
# hit wicket               10
# obstructing the field    2
# Name: dismissal_kind, dtype: int64

# %%
sns.countplot(y='dismissal_kind',data=deliveries,order= deliveries.dismissal_kind.value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='dismissal_kind'>

# %% [markdown]
# ### Analysis of Fielders

# %% [markdown]
# #### Most number of Catches by a Player

# %%
catches = deliveries[deliveries['dismissal_kind']=='caught']['fielder'].value_counts()
catches.head(10)
# Out:
# KD Karthik        109
# SK Raina          99
# MS Dhoni          98
# AB de Villiers    93
# RV Uthappa        84
# RG Sharma         82
# KA Pollard        76
# V Kohli           73
# PA Patel          69
# S Dhawan          68
# Name: fielder, dtype: int64

# %%
deliveries[deliveries['dismissal_kind']=='caught']['fielder'].value_counts().head(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Most number of Stumped by a Wicket Keeper

# %%
stumped = deliveries[deliveries['dismissal_kind']=='stumped']['fielder'].value_counts()
stumped.head(10)
# Out:
# MS Dhoni         38
# RV Uthappa       32
# KD Karthik       29
# WP Saha          18
# AC Gilchrist     16
# PA Patel         16
# NV Ojha          10
# RR Pant          9
# KC Sangakkara    9
# Q de Kock        8
# Name: fielder, dtype: int64

# %%
deliveries[deliveries['dismissal_kind']=='stumped']['fielder'].value_counts().head(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Most Valuable Player of IPL

# %%
top_players = matches.player_of_match.value_counts()[:10]
#sns.barplot(x="day", y="total_bill", data=df)
fig, ax = plt.subplots(figsize=(15,8))
ax.set_ylim([0,20])
ax.set_ylabel("Count")
ax.set_title("Top player of the match Winners")
top_players.plot.bar()
sns.barplot(x = top_players.index, y = top_players, orient='v', palette='Paired');
plt.show()

# %% [markdown]
# __CH Gayle__ & __AB de Villiers__ are the most Successful players in all match winners

# %% [markdown]
# ### Analysis of Umpires standing in the Matches

# %%
df_umpire = pd.melt(matches, id_vars=['id'], value_vars=['umpire1', 'umpire2'])

# %%
u = df_umpire.value.value_counts()[:10]
labels = np.array(u.index)
ind = np.arange(len(labels))
width = 0.9
fig, ax = plt.subplots(figsize=(15,8))
rects = ax.bar(ind, np.array(u), width=width,)
ax.set_xticks(ind+((width)/2.))
ax.set_xticklabels(labels, rotation='vertical')
ax.set_ylabel("Count")
ax.set_title("Top Umpires")
autolabel(rects)
plt.show()

# %% [markdown]
# __S.Ravi__ has officiated the most number of IPL matches, followed by __HDPK Dharmasena__

# %% [markdown]
# ## Inferences and Conclusion

# %% [markdown]
# __Summary of Exploratory Data Analysis:__

# %% [markdown]
# - Mumbai Indians is the most successful team in IPL.
#
# - Mumbai Indians has won the most number of toss.
#
# - There were more matches won by chasing the total than defending.
#
# - The Mumbai city has hosted the most number of IPL matches.
#
# - Chris Gayle has won the maximum number of player of the match title.
#
# - Winning toss gives a slight edge(52% probability of winning) against the opponents.
#
# - S. Ravi has officiated the most number of IPL matches on-field.
#
# - Eden Gardens has hosted the maximum number of IPL matches.
